# %%
import pandas as pd
import numpy

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-e4796ec3-e30d-4a93-8a28-cba5d1af32cf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e4796ec3-e30d-4a93-8a28-cba5d1af32cf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install pydantic==1.8.2 typeguard==2.13.0

# %%
# !pip install pandas-profiling
# Out:
# ...
#   Using cached pydantic-2.5.2-py3-none-any.whl (381 kB)
# ...
#   Using cached typeguard-4.1.5-py3-none-any.whl (34 kB)
# ...
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 2.13.0
#     Uninstalling typeguard-2.13.0:
#       Successfully uninstalled typeguard-2.13.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.8.2
#     Uninstalling pydantic-1.8.2:
#       Successfully uninstalled pydantic-1.8.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# ...

# %%
# !pip install pydantic==1.8.2
# Out:
# ...
#   Using cached pydantic-1.8.2-py3-none-any.whl (126 kB)
# ...
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.5.2
#     Uninstalling pydantic-2.5.2:
#       Successfully uninstalled pydantic-2.5.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# inflect 7.0.0 requires pydantic>=1.9.1, but you have pydantic 1.8.2 which is incompatible.
# ydata-profiling 4.6.3 requires pydantic>=2, but you have pydantic 1.8.2 which is incompatible.
# ...

# %%
# !pip install lida==0.0.10
# !pip install llmx==0.0.15a0
# !pip install inflect==7.0.0
# !pip install ydata-profiling==4.6.3
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 750.0 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.5/221.5 kB 18.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 60.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 82.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 9.2 MB/s eta 0:00:00
# ...
#   Using cached pydantic-2.5.2-py3-none-any.whl (381 kB)
# ...

# %%
# %tensorflow_version 2.x
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
from pandas_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-e2a33329b6f0> in <cell line: 1>()
# ----> 1 from pandas_profiling import ProfileReport
#
# /usr/local/lib/python3.10/dist-packages/pandas_profiling/__init__.py in <module>
#       6 from warnings import warn
#       7
# ----> 8 from pandas_profiling.compare_reports import compare
#       9 from pandas_profiling.controller import pandas_decorator
#      10 from pandas_profiling.profile_report import ProfileReport
#
# /usr/local/lib/python3.10/dist-packages/pandas_profiling/compare_reports.py in <module>
#       6 from pandas_profiling.config import Correlation, Settings
#       7 from pandas_profiling.model.alerts import Alert
# ----> 8 from pandas_profiling.profile_report import ProfileReport
#       9
#      10
#
# /usr/local/lib/python3.10/dist-packages/pandas_profiling/profile_report.py in <module>
# ...

# %%
url = 'Charades_v1_clean_train.csv'
df = pd.read_csv(url)

# Create a ProfileReport with an empty string as config_file
profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True, config_file='')

# Display the report
profile.to_notebook_iframe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-ded1e651d821> in <cell line: 5>()
#       3
#       4 # Create a ProfileReport with an empty string as config_file
# ----> 5 profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True, config_file='')
#       6
#       7 # Display the report
#
# NameError: name 'ProfileReport' is not defined

# %%
df.head(10)

# %%
df.columns

# %% [markdown]
# # HEATMAP

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame
url = 'Charades_v1_clean_train.csv'
df = pd.read_csv(url)

numerical_columns = ['id', 'relevance', 'verified', 'length']

# Calculate the correlation matrix
correlation_matrix = df[numerical_columns].corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('confusion Matrix')
plt.show()
# Out:
# <ipython-input-18-2fc3af102909>:12: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df[numerical_columns].corr()
