# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-23d5b703-6066-4b5f-86f8-8614c1d27f6c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-23d5b703-6066-4b5f-86f8-8614c1d27f6c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('sales_data_samples.csv',sep=',',encoding='latin-1')

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# Z-score                0
# dtype: int64

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
# df['ORDERLINENUMBER']

# FINDING THE outlier

# z-score = x-mean/sd
df['Zscore'] = df['ORDERLINENUMBER']-df['ORDERLINENUMBER'].mean()/df['ORDERLINENUMBER'].std()

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
import numpy as np

# Calculate z-score
df['Zscore'] = (df['ORDERLINENUMBER'] - df['ORDERLINENUMBER'].mean()) / df['ORDERLINENUMBER'].std()

# Define the threshold
threshold = 3

# # Identify outliers
Outliers_cities = df.query('Zscore > 2')['CITY']

# %%
x = np.array(Outliers_cities)
x
# Out:
# array(['San Francisco', 'San Francisco', 'New Bedford', 'Cowes', 'Boston',
#        'Kobenhavn', 'Madrid', 'Bergen', 'Reggio Emilia', 'Nashua',
#        'Madrid', 'New Bedford', 'NYC', 'NYC', 'Manchester', 'Madrid',
#        'Manchester', 'Manchester', 'Osaka', 'Torino', 'San Rafael',
#        'Nashua', 'NYC', 'San Rafael', 'Torino', 'San Rafael', 'Singapore',
#        'Versailles', 'San Rafael', 'Singapore', 'Madrid', 'Reims',
#        'San Francisco', 'Manchester', 'Bergamo', 'Madrid', 'Cowes',
#        'Reims', 'Manchester', 'NYC', 'Singapore', 'Bruxelles', 'Bergen',
#        'Gensve', 'Stavern', 'Madrid', 'Bergen', 'NYC', 'Marseille',
#        'Koln', 'Bergamo', 'Reims', 'San Rafael', 'New Bedford',
#        'Manchester', 'Glen Waverly', 'Torino', 'Boston', 'Marseille',
#        'Gensve', 'Koln', 'Bergamo', 'Glen Waverly', 'San Rafael',
#        'San Francisco', 'Paris', 'Manchester', 'Pasadena', 'Reims',
#        'Versailles', 'Boras', 'Versailles', 'Singapore', 'Makati City',
# ...

# %%
df['Zscore'].head(10)
# Out:
# 0   -1.056871
# 1   -0.346954
# 2   -1.056871
# 3   -0.110314
# 4    1.782800
# 5   -1.293511
# 6    0.599604
# 7   -1.293511
# 8   -1.056871
# 9    1.782800
# Name: Zscore, dtype: float64
