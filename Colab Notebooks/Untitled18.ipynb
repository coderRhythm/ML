# %%
import pandas as pd
import numpy as np
# Out:
# Z-scores: 0   -0.502219
# 1   -0.474574
# 2   -0.446929
# 3   -0.419284
# 4   -0.391639
# 5    2.234643
# Name: value, dtype: float64
# Indices of outliers: []
