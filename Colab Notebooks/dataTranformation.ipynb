# %% [markdown]
# Outlier analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Define your dataset
dataset = [11, 10, 12, 14, 12, 15, 14, 13, 15, 102, 12, 14, 17, 19, 107, 10, 13, 12, 14, 12, 108, 12, 11, 14, 13, 15, 10, 15, 12, 10, 14, 13, 15, 10]
df = pd.DataFrame(dataset)
# Calculate the mean using NumPy
mean = df.mean(axis=0)
print(mean)
# Out:
# 0    21.176471
# dtype: float64

# %% [markdown]
# **By using z score**

# %%
# Define your dataset
dataset = [11, 10, 12, 14, 12, 15, 14, 13, 15, 102, 12, 14, 17, 19, 107, 10, 13, 12, 14, 12, 108, 12, 11, 14, 13, 15, 10, 15, 12, 10, 14, 13, 15, 10]

# Calculate the mean using NumPy
mean = np.mean(dataset)
print(mean)
# Calculate the standard deviation
std_dev = np.std(dataset)

# Define a threshold for identifying outliers (commonly 2 or 3)
threshold = 3

# Identify and print outliers using a for loop
outliers = []
for x in dataset:
    z_score = abs((x - mean) / std_dev)
    if z_score > threshold:
        outliers.append(x)

print("Identified outliers:", outliers)
# Out:
# 21.176470588235293
# Identified outliers: [102, 107, 108]

# %% [markdown]
# ## using IQR

# %%
import numpy as np

# Sample data (replace this with your data)
data = [11, 10, 12, 14, 12, 15, 14, 13, 15, 102, 12, 14, 17, 19, 107, 10, 13, 12, 14, 12, 108, 12, 11, 14, 13, 15, 10, 15, 12, 10, 14, 13, 15, 10]

# Step 2: Calculate the IQR (Interquartile Range)
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1

# Step 4: Define a threshold for identifying outliers
threshold = 1.5

# Step 5: Calculate the lower and upper bounds
lower_bound = Q1 - (threshold * IQR)
upper_bound = Q3 + (threshold * IQR)

print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)

# Step 6: Identify and display the outliers
outliers = [x for x in data if x < lower_bound or x > upper_bound]

print("Outliers:", outliers)
# Out:
# Lower Bound: 7.5
# Upper Bound: 19.5
# Outliers: [102, 107, 108]

# %%
from google.colab import files

# Use files.upload() to upload a file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1822387a-0661-4b72-b003-16f97914557d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1822387a-0661-4b72-b003-16f97914557d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('PNQ_AQI.csv')

# %%
# Perform correlation analysis
correlation_matrix = df.corr()

# Display the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#             RSPM µg/m3       SPM  CO2 µg/m3       AQI
# RSPM µg/m3    1.000000  0.807315        NaN  0.932417
# SPM           0.807315  1.000000        NaN  0.752509
# CO2 µg/m3          NaN       NaN        NaN       NaN
# AQI           0.932417  0.752509        NaN  1.000000
# <ipython-input-19-8da9f1b2bec7>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
from google.colab import files

# Use files.upload() to upload a file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-72a5b01f-e0d1-4cec-9077-c70fbbe87c6d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-72a5b01f-e0d1-4cec-9077-c70fbbe87c6d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('AXISBANK.NS.csv')

# %%
# Perform correlation analysis
correlation_matrix = df.corr()

# Display the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999221  0.999154  0.998484   0.998232 -0.107330
# High       0.999221  1.000000  0.998873  0.999358   0.999189 -0.092289
# Low        0.999154  0.998873  1.000000  0.999254   0.998880 -0.118786
# Close      0.998484  0.999358  0.999254  1.000000   0.999707 -0.104349
# Adj Close  0.998232  0.999189  0.998880  0.999707   1.000000 -0.094028
# Volume    -0.107330 -0.092289 -0.118786 -0.104349  -0.094028  1.000000
# <ipython-input-22-8da9f1b2bec7>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
print(df)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2012-01-02  162.000000  163.000000  156.800003  158.960007  148.216110
# 1     2012-01-03  161.020004  168.380005  160.729996  167.509995  156.188202
# 2     2012-01-04  168.960007  171.199997  166.380005  169.630005  158.164932
# 3     2012-01-05  169.800003  175.759995  169.009995  174.130005  162.360794
# 4     2012-01-06  172.559998  173.199997  167.259995  170.699997  159.162598
# ...          ...         ...         ...         ...         ...         ...
# 2466  2021-12-27  663.049988  674.599976  655.950012  672.150024  671.128479
# 2467  2021-12-28  677.299988  680.849976  672.000000  675.450012  674.423401
# 2468  2021-12-29  674.500000  679.599976  667.250000  670.500000  669.480957
# 2469  2021-12-30  668.000000  673.099976  664.500000  668.849976  667.833435
# 2470  2021-12-31  672.950012  686.500000  671.200012  678.549988  677.518677
#
#           Volume
# 0      9727265.0
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('AXISBANK.NS.csv')
correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# <ipython-input-25-d74984e0d700>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
import pandas as pd


# Select the top 5 rows
top_5_rows = df.head(5)

# Print the top 5 rows
print(top_5_rows)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2012-01-02  162.000000  163.000000  156.800003  158.960007  148.216110
# 1  2012-01-03  161.020004  168.380005  160.729996  167.509995  156.188202
# 2  2012-01-04  168.960007  171.199997  166.380005  169.630005  158.164932
# 3  2012-01-05  169.800003  175.759995  169.009995  174.130005  162.360794
# 4  2012-01-06  172.559998  173.199997  167.259995  170.699997  159.162598
#
#        Volume
# 0   9727265.0
# 1  10710050.0
# 2  16936750.0
# 3  16901170.0
# 4  12345325.0

# %%
# Select the top 5 rows
top_5_rows = df.head(5)

# Create a correlation matrix for the top 5 rows
correlation_matrix = top_5_rows.corr()

# Create a heatmap
plt.figure(figsize=(15, 20))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap for Top 5 Rows')
plt.show()
# Out:
# <ipython-input-28-2c76a74a1ae6>:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = top_5_rows.corr()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame named df

# Select only the numeric columns
numeric_columns = df.select_dtypes(include=[np.number])

# Calculate the correlation matrix
correlation_matrix = np.corrcoef(numeric_columns.to_numpy(), rowvar=False)

# Create a heatmap
plt.figure(figsize=(15, 20))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap for Top 5 Rows')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
